# %%
import sympy as sym
from sympy import pprint
import numpy as np
import matplotlib 
from IPython.display import display, Math, Latex
sym.init_printing(use_latex=True)
T_x, T_y, T_z, T_a, T_b, T_c, T_d, C = sym.symbols('T_x, T_y, T_z, T_a, T_b, T_c, T_d, C')

#equations:
# T_x = sin(45)*(T_a+T_b-T_c-T_d) -> eqA = sin(45)*(T_a+T_b-T_c-T_d)-T_X
# T_y = cos(45)*(T_a-T_b-T_c+T_d) -> eqB = cos(45)*(T_a-T_b-T_c+T_d)-T_y
# T_z = cos(53)*(T_a+T_b+T_c+T_d) -> eqC = cos(53)*(T_a+T_b+T_c+T_d)-T_z
# C = T_a**2+T_b**2+T_c**2+T_d**2 -> eqD = T_a**2+T_b**2+T_c**2+T_d**2-C
eqA = np.sin(45*2*np.pi/360)*(T_a+T_b-T_c-T_d)-T_x
eqB = np.cos(45*2*np.pi/360)*(T_a-T_b-T_c+T_d)-T_y
eqC = np.sin(53*2*np.pi/360)*(T_a+T_b+T_c+T_d)-T_z
eqD = T_a**2+T_b**2+T_c**2+T_d**2-C
eqns = [eqA,eqB,eqC,eqD]
solutions = sym.solve(eqns, T_a, T_b, T_c, T_d, dict=True)
#print(solutions)
pprint(solutions)
#display(Math(r'T_a=0.353553390593274T_x + 0.353553390593274T_y + 0.415410035280621T_z - 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
#display(Math(r'T_b=0.353553390593274T_x - 0.353553390593274T_y + 0.415410035280621T_z + 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
#display(Math(r'T_c=-0.353553390593274T_x - 0.353553390593274T_y + 0.415410035280621T_z - 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
#display(Math(r'T_d=-0.353553390593274T_x + 0.353553390593274T_y + 0.415410035280621T_z + 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))

#display(Math(r'T_a=0.353553390593274T_x + 0.353553390593274T_y + 0.415410035280621T_z + 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
#display(Math(r'T_b=0.353553390593274T_x - 0.353553390593274T_y + 0.415410035280621T_z - 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
#display(Math(r'T_c=-0.353553390593274T_x - 0.353553390593274T_y + 0.415410035280621T_z + 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
#display(Math(r'T_d=-0.353553390593274T_x + 0.353553390593274T_y + 0.415410035280621T_z - 1.06344969031839*10^{-43}\sqrt(2.21057935846863*10^{85}C - 1.10528967923432*10^{85}T_x^2 - 1.10528967923431*10^{85}T_y^2 - 1.52587890625*10^{85}T_z^2)'))
# Out:
# ⎡⎧
# ⎢⎨
# ⎣⎩Tₐ: 0.353553390593274⋅Tₓ + 0.353553390593274⋅T_y + 0.313033914539056⋅T_z - -
#
#                           ____________________________________________________
#                          ╱
#  -1.50256278978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)
#
# _________________________________________________________________________
#    2                                 2                                 2
# ⋅Tₓ  - -5.53662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  , T_b
#
#
#
# : 0.353553390593274⋅Tₓ - - -0.353553390593274⋅T_y + 0.313033914539056⋅T_z + 1.
#
#                       ________________________________________________________
#                      ╱                                                       2
# 50256278978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅Tₓ
#
# _____________________________________________________________________
#                                  2                                 2
#  - -5.53662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  , T_c: --
#
#
#
#  -0.353553390593274⋅Tₓ - - -0.353553390593274⋅T_y + 0.313033914539056⋅T_z - -
#
#                          _____________________________________________________
#                         ╱
# -1.50256278978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅
#
# ________________________________________________________________________
#   2                                 2                                 2
# Tₓ  - -5.53662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  , T_d:
#
#
#
#  -- -0.353553390593274⋅Tₓ + 0.353553390593274⋅T_y + 0.313033914539056⋅T_z + 1.
#
#                       ________________________________________________________
#                      ╱                                                       2
# 50256278978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅Tₓ
#
# _____________________________________________________________________⎫  ⎧
#                                  2                                 2 ⎬  ⎨
#  - -5.53662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  ⎭, ⎩Tₐ: 0
#
#
#
# .353553390593274⋅Tₓ + 0.353553390593274⋅T_y + 0.313033914539056⋅T_z + 1.502562
#
#                 ______________________________________________________________
#                ╱                                                       2
# 78978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅Tₓ  - -5.
#
# _______________________________________________________________
#                            2                                 2
# 53662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  , T_b: 0.353553
#
#
#
# 390593274⋅Tₓ - - -0.353553390593274⋅T_y + 0.313033914539056⋅T_z - - -1.5025627
#
#                _______________________________________________________________
#               ╱                                                       2
# 8978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅Tₓ  - -5.5
#
# ______________________________________________________________
#                           2                                 2
# 3662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  , T_c: -- -0.353
#
#
#
# 553390593274⋅Tₓ - - -0.353553390593274⋅T_y + 0.313033914539056⋅T_z + 1.5025627
#
#                _______________________________________________________________
#               ╱                                                       2
# 8978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅Tₓ  - -5.5
#
# ______________________________________________________________
#                           2                                 2
# 3662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  , T_d: -- -0.353
#
#
#
# 553390593274⋅Tₓ + 0.353553390593274⋅T_y + 0.313033914539056⋅T_z - - -1.5025627
#
#                _______________________________________________________________
#               ╱                                                       2
# 8978747e-44⋅╲╱  1.10732409359115e+87⋅C - -5.53662046795573e+86⋅(-1)⋅Tₓ  - -5.5
#
# ______________________________________________________________⎫⎤
#                           2                                 2 ⎬⎥
# 3662046795572e+86⋅(-1)⋅T_y  - -4.34027777777778e+86⋅(-1)⋅T_z  ⎭⎦

# %%
c_1=(1.06344969031839*10**-43)**2*(2.21057935846863*10**85)
c_2=(1.06344969031839*10**-43)**2*(1.10528967923432*10**85)
c_3=(1.06344969031839*10**-43)**2*(1.10528967923431*10**85)
c_4=(1.06344969031839*10**-43)**2*(1.52587890625*10**85)
c_5=np.sin(45*2*np.pi/360)/2
print(c_1,c_2,c_3,c_4,c_5)
# Out:
# (0.25000000000000033, 0.12500000000000075, 0.12499999999999963, 0.1725654974118469, 0.35355339059327373)

# %%
from IPython.display import display, Math, Latex
print('solution 1:')
display(Math(r'T_a=0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
display(Math(r'T_b=0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
display(Math(r'T_c=-0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
display(Math(r'T_d=-0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
print('solution 2:')
display(Math(r'T_a=0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
display(Math(r'T_b=0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
display(Math(r'T_c=-0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
display(Math(r'T_d=-0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)'))
# Out:
# solution 1:
# $$T_a=0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# $$T_b=0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# $$T_c=-0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# $$T_d=-0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# solution 2:
# $$T_a=0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# $$T_b=0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# $$T_c=-0.3535533905932737T_x - 0.3535533905932737T_y + 0.415410035280621T_z + \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
# $$T_d=-0.3535533905932737T_x + 0.3535533905932737T_y + 0.415410035280621T_z - \sqrt(0.25C - 0.125T_x^2 - 0.125T_y^2 - 0.1725654974118469T_z^2)$$
