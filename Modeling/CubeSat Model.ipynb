# %% [markdown]
# by Jeremy Louke
#
# ## Intro
#
# The purpose of this notebook is for modeling the CubeSat in order to design a control system.

# %%
from oct2py import octave
import matplotlib.pylab as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
import os

# Graphing helper function
def setup_graph(title='',x_label='', y_label='', fig_size=None):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0],
                            fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# this is the path of the code I wish to use
octave.addpath(os.path.dirname(os.path.realpath('CubeSat_Model.m')))

# call the script
octave.eval('CubeSat_Model')
# Out:
# /Users/will/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
t = octave.pull('t')
y_x = octave.pull('y_x')

setup_graph('Step response', 'time (s)', 'Amplitude (deg/s)', (9,6.5))
plt.plot(t, y_x)
plt.show()

# %%
omega_a = octave.pull('omega_a')
omega_b = octave.pull('omega_b')
omega_c = octave.pull('omega_c')
omega_d = octave.pull('omega_d')

setup_graph('Motor velocities', 'time (s)', 'Motor Angular Velocity (deg/s)', (9,6.5))
plt.plot(t, omega_a, t, omega_b, t, omega_c, t, omega_d)
plt.legend(['Motor A','Motor B','Motor C','Motor D'], loc='best')
